# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import networkx as nx
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
# from funcions_v2 import *

# %%
import sys
sys.path.append('/nfs/pic.es/user/m/mgraell/Halo_ML')
from  funcions_v2 import *

# %% [markdown]
# # Dades

# %%
cat = get_dataset('/data/astro/scratch/lcabayol/EUCLID/GHalo_FS/FS2_clusters_z04.parquet',
                  ['halo_id','color_kind','x_in_halo', 'y_in_halo','z_in_halo', 'radis', 'abs_mag_r01',
                   'g01r01_hod','ax_halo', 'ay_halo', 'az_halo','b_to_a_halo','c_to_a_halo'],
                   400,3000)
cat = cat[cat['color_kind']==2]
len(cat)/1e6
# Out:
# 16.373172

# %%
# Llista de halos amb dades i labels
halo_id_values = np.unique(cat['halo_id'].to_numpy())
halo_id_values, len(halo_id_values)

llista_tensors = []
for halo_id in halo_id_values:
    llista_tensors.append(torch.tensor(cat[cat['halo_id'] == halo_id].to_numpy()))

len(llista_tensors)

# Separo dades i labels; de labels agafo c i b to a
X_list=[]
y_list=[]
print(llista_tensors[0].shape)
for i in range(len(halo_id_values)):
    X_list.append(llista_tensors[i][:,2:-5])
    y_list.append(llista_tensors[i][:,-2:])
print(len(X_list), len(y_list), X_list[0].shape, y_list[0].shape, X_list[0].dtype, y_list[0].dtype)


# Faig que només hi hagi una label per halo, no una per galàxia.
unique_y = []
for i in range(len(y_list)):
    unique_y.append(torch.unique(y_list[i]).squeeze())
# Out:
# torch.Size([1153, 13])
# 25607 25607 torch.Size([1153, 6]) torch.Size([1153, 2]) torch.float64 torch.float64

# %%
del cat, llista_tensors

# %%
# Tot el procés pot trigar molt, així que guardo passos intermitjos
torch.save(unique_y, 'unique_y_prov')
torch.save(X_list, 'X_list_prov')

# %%
unique_y = torch.load('unique_y_prov')
X_list = torch.load('X_list_prov')
X_list_full = X_list.copy()
unique_y_full = unique_y.copy()

# %%
for i in range(len(X_list)):
    if len(X_list[i]) <= 400 or len(X_list[i]) > 3000:
        X_list[i] = 'per eliminar'
        unique_y[i] = 'per eliminar'

X_list = [halo for halo in X_list if halo != 'per eliminar']
unique_y = [halo for halo in unique_y if halo != 'per eliminar']

# %%
# Aquí repeteixo els halos amb formes menys representades; els histogrames
# mostren la freqüència dels diferents b/a abans i després de fer-ho.

unique_y_tensor = torch.tensor(np.array(unique_y))


counts, bins = torch.histogram(unique_y_tensor[:,0], bins=10)
plt.plot(bins.numpy()[1:], counts.numpy())
plt.title('Counts de b/a al catàleg') 
plt.show()
moda = max(counts)

X_list_pes = X_list.copy()
unique_y_pes = list(unique_y_tensor)
for j in range(len(unique_y_tensor)):
    halo_shape = unique_y_tensor[j]
    halo_data = X_list[j]
    for i in range(len(counts)):
        if halo_shape[0] > bins[i] and halo_shape[0] < bins[i+1]:
            size= random_round(moda/(2*counts[i]) - 1/2)
            for k in range(size):
                insert_index =  np.random.randint(0,len(unique_y_pes))
                unique_y_pes.insert(insert_index, halo_shape)
                X_list_pes.insert(insert_index, halo_data)

unique_y_pes_tensor = unique_y_pes[0]
for i in range(1, len(unique_y)):
    unique_y_pes_tensor = torch.vstack((unique_y_pes_tensor, unique_y_pes[i]))


counts, bins = torch.histogram(unique_y_pes_tensor[:,0], bins=10)
plt.plot(bins.numpy()[1:], counts.numpy())
plt.title('Counts de b/a després del "pesatge"')
plt.show()
unique_y_pes_tensor.shape, len(unique_y), len(unique_y_pes), len(X_list), len(X_list_pes)
# Out:
# (torch.Size([15925, 2]), 15925, 29372, 15925, 29372)

# %%
# Faig batches
X_train, X_test = make_test_train_batched(X_list)
y_train_list, y_test_list = make_test_train_batched(unique_y)

X_train_pes, X_test_pes = make_test_train_batched(X_list_pes)
y_train_pes_list, y_test_pes_list = make_test_train_batched(unique_y_pes)

_, X_test_full = make_test_train_batched(X_list_full)
_, y_test_full = make_test_train_batched(unique_y_full)
# Out:
# /nfs/pic.es/user/m/mgraell/Halo_ML/funcions_v2.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list = [torch.tensor(sample).to(torch.float32) for sample in batch]

# %%
del X_list, unique_y, X_list_pes, unique_y_pes, X_list_full, unique_y_full

# %%
y_test = torch.tensor(np.array(y_test_list))
y_train = torch.tensor(np.array(y_train_list))
y_test_pes = torch.tensor(np.array(y_test_pes_list))
y_train_pes = torch.tensor(np.array(y_train_pes_list))

# %%
len(X_train), len(X_train[0]), X_train[0][0].shape, len(X_test), len(X_train_pes), len(X_test_pes), y_train.shape, y_test.shape, y_train_pes.shape, y_test_pes.shape, len(X_test_full), len(X_test_full[0])
# Out:
# (99,
#  128,
#  torch.Size([1153, 6]),
#  24,
#  183,
#  45,
#  torch.Size([99, 128, 2]),
#  torch.Size([24, 128, 2]),
#  torch.Size([183, 128, 2]),
#  torch.Size([45, 128, 2]),
#  40,
#  128)

# %%
X_test_analitic = X_test_full.copy()
for i in range(len(X_test_analitic)):
    for j in range(len(X_test_analitic[i])):
        halo = X_test_analitic[i][j]
        X_test_analitic[i][j] = [gal for gal in halo if gal[4] != 0]

# %%
torch.save(y_test, '/nfs/pic.es/user/m/mgraell/Halo_ML/y_test_bctoa')
torch.save(X_test, '/nfs/pic.es/user/m/mgraell/Halo_ML/X_test_bctoa')
torch.save(y_train_pes, '/nfs/pic.es/user/m/mgraell/Halo_ML/y_train_pes_bctoa')
torch.save(X_train_pes, '/nfs/pic.es/user/m/mgraell/Halo_ML/X_train_pes_bctoa')
torch.save(X_test_full, '/nfs/pic.es/user/m/mgraell/Halo_ML/X_test_full_bctoa')
torch.save(y_test_full, '/nfs/pic.es/user/m/mgraell/Halo_ML/y_test_full_bctoa')
torch.save(X_test_analitic, '/nfs/pic.es/user/m/mgraell/Halo_ML/X_test_analitic_bctoa')

# %%
del y_test, X_test, y_train_pes, X_train_pes, X_test_full, y_test_full, X_test_analitic

# %% [markdown]
# # Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import networkx as nx
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
#from funcions_v2 import *
import scipy as scp

# %%
y_test = torch.load('/nfs/pic.es/user/m/mgraell/Halo_ML/y_test_bctoa')
y_train = torch.load('/nfs/pic.es/user/m/mgraell/Halo_ML/y_train_pes_bctoa')
X_test = torch.load('/nfs/pic.es/user/m/mgraell/Halo_ML/X_test_bctoa')
X_train = torch.load('/nfs/pic.es/user/m/mgraell/Halo_ML/X_train_pes_bctoa')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
class Model(nn.Module):
    def __init__(self, input_len:int, output_len:int, batch_size:int):
        super().__init__()
                        
        self.lin_block = nn.Sequential(
                                nn.Linear(input_len, 256),
                                nn.ELU(),
                                nn.Linear(256, 256),                                
                            )
        self.lin_block2 = nn.Sequential(
                                nn.Linear(256, 256),
                                nn.ELU(),
                                nn.Linear(256, output_len),
                            )
        self.batch_size = batch_size
        self.input_len = input_len
        self.output_len = output_len



    def forward(self, data):
        x = [self.lin_block(x_elem.to(device)) for x_elem in data]
        
        # xsum =[xx.sum(dim=0) for xx in x]
        # x = torch.stack(xsum)
        
        max_len = max([len(x_elem) for x_elem in data])

        padded_x = [torch.nn.functional.pad(x_elem, (0, 0, 0, max_len - len(x_elem))) for x_elem in x]

        stacked_data = torch.stack(padded_x)

        x = stacked_data.sum(dim=1)
        
        output = self.lin_block2(x)

        return output.squeeze()

# %%
torch.manual_seed(42)
input_len = 6
output_len = 2
model = Model(input_len=input_len, output_len=output_len, batch_size = 128).to(device)

# %%
model(X_test[0]).shape, y_test.shape, len(X_test)
# Out:
# (torch.Size([128, 2]), torch.Size([24, 128, 2]), 24)

# %%
def get_loss_acc(model, X, y, loss_fn, exigencia):
    model.eval()
    test_loss = 0
    if output_len > 1:
        acc = np.zeros(output_len)
    else:
        acc = 0
    with torch.inference_mode():
        for i in range(len(X)):
            output = model(X[i]).to(device)
            labels = y[i].to(device)
            test_loss += loss_fn(output, labels)
            encerts = 0
            if output_len > 1:
                for j in range(len(output)):  
                    rel_err = torch.abs(output[j]-labels[j])*100/labels[j] 
                    for k in range(output_len):    
                        if rel_err[k] < exigencia:
                            acc[k] += 1/len(output)
            else:
                for j in range(len(output)):  
                    rel_err = torch.abs(output[j]-labels[j])*100/labels[j] 
                    if rel_err < exigencia:
                        acc += 1/len(output)                

        test_loss /= len(X)
        acc *= 100/len(X) 
        print(f'Test loss: {test_loss: .5f}, Accuracy: {np.round(acc, 2)} %')
        return test_loss, acc

def train_step(model, X, y, loss_fn, opt, scheduler, use_scheduler, epoch, print_every):
    train_loss = 0
    model.train()
    
    for i in range(len(X)):
        opt.zero_grad()
        output = model(X[i]).to(device)
        

        loss = loss_fn(output, y[i].to(device))
        loss.backward()
        opt.step()

        train_loss += loss.item()

    train_loss /= len(X)
    if epoch % print_every == 0:
        print(f'Train loss: {train_loss:.5f}')
    if use_scheduler:
        scheduler.step(loss)


def test_step(model, X, y, loss_fn, epoch, print_every, epochs, exigencia):
    if epoch % print_every == 0:
        test_loss, acc = get_loss_acc(model, X, y, loss_fn, exigencia)
        print(np.round(epoch/epochs *100, 1), '%')

# %%
lr = 1e-2 
mode = 'min'
factor = 0.2
patience = 300
threshold = 0.0001
threshold_mode = 'abs'

# %%
opt = torch.optim.Adagrad(model.parameters(), lr=lr)
loss_fn = nn.L1Loss()
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, mode=mode, factor=factor, patience=patience, threshold=threshold, threshold_mode=threshold_mode)
save_file = 'bctoa_model_blau_0.pt'
save_file2 = 'prova.pt'

# %%
# %%time
epochs = 3000
print_every = 10

for epoch in range(epochs):
    train_step(model=model, X=X_train, y=y_train, loss_fn=loss_fn, opt=opt,
                scheduler=scheduler, use_scheduler=False, epoch=epoch, print_every=print_every)
    test_step(model=model, X=X_test, y=y_test, loss_fn=loss_fn, epoch=epoch,
              print_every=print_every, epochs=epochs, exigencia=10)
    if epoch % 100 == 0:
        torch.save(model.state_dict(), f'/nfs/pic.es/user/m/mgraell/Halo_ML/{save_file}')
# Out:
# Train loss: 302.32046
# Test loss:  20.58742, Accuracy: [0. 0.] %
# 0.0 %
# Train loss: 1.66651
# Test loss:  0.31860, Accuracy: [ 0.75 22.75] %
# 0.3 %
# Train loss: 0.14533
# Test loss:  0.08762, Accuracy: [50.33 45.77] %
# 0.7 %
# Train loss: 0.10354
# Test loss:  0.07906, Accuracy: [47.88 58.53] %
# 1.0 %
# Train loss: 0.09012
# Test loss:  0.07200, Accuracy: [53.45 58.11] %
# 1.3 %
# Train loss: 0.08691
# Test loss:  0.07901, Accuracy: [47.56 55.05] %
# 1.7 %
# Train loss: 0.08362
# Test loss:  0.07717, Accuracy: [47.79 57.26] %
# 2.0 %
# Train loss: 0.08353
# Test loss:  0.06866, Accuracy: [56.05 60.71] %
# 2.3 %
# Train loss: 0.07915
# Test loss:  0.06695, Accuracy: [54.82 64.55] %
# 2.7 %
# Train loss: 0.33157
# Test loss:  0.27722, Accuracy: [1.6 5.4] %
# 3.0 %
# Train loss: 0.08204
# Test loss:  0.06480, Accuracy: [57.85 64.32] %
# 3.3 %
# Train loss: 0.07779
# Test loss:  0.06570, Accuracy: [56.93 63.38] %
# 3.7 %
# Train loss: 0.07518
# Test loss:  0.06588, Accuracy: [55.89 64.06] %
# 4.0 %
# Train loss: 0.07439
# Test loss:  0.06809, Accuracy: [54.95 61.17] %
# 4.3 %
# Train loss: 0.07467
# Test loss:  0.06341, Accuracy: [57.94 65.43] %
# 4.7 %
# Train loss: 0.07373
# Test loss:  0.06393, Accuracy: [57.03 65.66] %
# 5.0 %
# Train loss: 0.07266
# Test loss:  0.06258, Accuracy: [58.46 66.67] %
# 5.3 %
# Train loss: 0.07210
# Test loss:  0.06704, Accuracy: [53.68 64.23] %
# 5.7 %
# Train loss: 0.07220
# Test loss:  0.06331, Accuracy: [56.28 67.68] %
# 6.0 %
# Train loss: 0.07140
# Test loss:  0.06169, Accuracy: [58.2 68.2] %
# 6.3 %
# Train loss: 0.07922
# Test loss:  0.06482, Accuracy: [54.3  67.42] %
# 6.7 %
# Train loss: 0.07121
# Test loss:  0.06027, Accuracy: [59.54 69.89] %
# 7.0 %
# Train loss: 0.07063
# Test loss:  0.06019, Accuracy: [59.64 69.53] %
# 7.3 %
# Train loss: 0.07026
# Test loss:  0.06248, Accuracy: [58.89 65.79] %
# 7.7 %
# Train loss: 0.07070
# Test loss:  0.06471, Accuracy: [54.43 66.18] %
# 8.0 %
# Train loss: 0.07058
# Test loss:  0.06660, Accuracy: [55.37 62.89] %
# 8.3 %
# Train loss: 0.18949
# Test loss:  0.08999, Accuracy: [38.7  55.63] %
# 8.7 %
# Train loss: 0.07405
# Test loss:  0.06717, Accuracy: [55.37 62.04] %
# 9.0 %
# Train loss: 0.07039
# Test loss:  0.06665, Accuracy: [55.53 62.17] %
# 9.3 %
# Train loss: 0.12469
# Test loss:  0.08332, Accuracy: [44.37 51.53] %
# 9.7 %
# Train loss: 0.07005
# Test loss:  0.06434, Accuracy: [57.13 64.94] %
# 10.0 %
# Train loss: 0.06936
# Test loss:  0.06796, Accuracy: [55.6 61. ] %
# 10.3 %
# Train loss: 0.06838
# Test loss:  0.06878, Accuracy: [52.99 62.5 ] %
# 10.7 %
# Train loss: 0.06808
# Test loss:  0.05716, Accuracy: [60.64 73.4 ] %
# 11.0 %
# Train loss: 0.06803
# Test loss:  0.06900, Accuracy: [54.79 60.9 ] %
# 11.3 %
# Train loss: 0.06704
# Test loss:  0.05754, Accuracy: [61.04 73.08] %
# 11.7 %
# Train loss: 0.06740
# Test loss:  0.07032, Accuracy: [55.5  57.49] %
# 12.0 %
# Train loss: 0.06981
# Test loss:  0.05838, Accuracy: [60.22 71.68] %
# 12.3 %
# Train loss: 0.06704
# Test loss:  0.06726, Accuracy: [53.16 63.9 ] %
# 12.7 %
# Train loss: 0.06682
# Test loss:  0.06419, Accuracy: [56.64 65.66] %
# 13.0 %
# Train loss: 0.06600
# Test loss:  0.06758, Accuracy: [53.94 62.96] %
# 13.3 %
# Train loss: 0.06632
# Test loss:  0.07276, Accuracy: [58.2  52.93] %
# 13.7 %
# Train loss: 0.06547
# Test loss:  0.06757, Accuracy: [52.34 64.75] %
# 14.0 %
# Train loss: 0.06572
# Test loss:  0.06524, Accuracy: [54.98 65.1 ] %
# 14.3 %
# Train loss: 0.06713
# Test loss:  0.05666, Accuracy: [60.42 73.6 ] %
# 14.7 %
# Train loss: 0.08142
# Test loss:  0.07465, Accuracy: [48.47 57.45] %
# 15.0 %
# Train loss: 0.06550
# Test loss:  0.06399, Accuracy: [57.03 65.17] %
# 15.3 %
# Train loss: 0.06504
# Test loss:  0.06857, Accuracy: [54.3  60.97] %
# 15.7 %
# Train loss: 0.08306
# Test loss:  0.06584, Accuracy: [55.57 62.04] %
# 16.0 %
# Train loss: 0.06556
# Test loss:  0.06016, Accuracy: [59.41 69.04] %
# 16.3 %
# Train loss: 0.06817
# Test loss:  0.06187, Accuracy: [59.6  65.62] %
# 16.7 %
# Train loss: 0.06459
# Test loss:  0.05576, Accuracy: [62.34 73.31] %
# 17.0 %
# Train loss: 0.07825
# Test loss:  0.05743, Accuracy: [60.29 72.04] %
# 17.3 %
# Train loss: 0.06355
# Test loss:  0.06291, Accuracy: [57.49 65.98] %
# 17.7 %
# Train loss: 0.06401
# Test loss:  0.05789, Accuracy: [60.03 71.78] %
# 18.0 %
# Train loss: 0.06259
# Test loss:  0.06799, Accuracy: [53.68 62.08] %
# 18.3 %
# Train loss: 0.06306
# Test loss:  0.07059, Accuracy: [52.25 59.83] %
# 18.7 %
# Train loss: 0.06237
# Test loss:  0.06272, Accuracy: [55.83 68.07] %
# 19.0 %
# Train loss: 0.06272
# Test loss:  0.06691, Accuracy: [53.13 63.93] %
# 19.3 %
# Train loss: 0.14251
# Test loss:  0.08859, Accuracy: [60.97 33.27] %
# 19.7 %
# Train loss: 0.06470
# Test loss:  0.06508, Accuracy: [53.87 65.27] %
# 20.0 %
# Train loss: 0.06302
# Test loss:  0.06219, Accuracy: [58.27 66.18] %
# 20.3 %
# Train loss: 0.06182
# Test loss:  0.05600, Accuracy: [62.6  71.48] %
# 20.7 %
# Train loss: 0.06096
# Test loss:  0.06290, Accuracy: [55.66 66.15] %
# 21.0 %
# Train loss: 0.06066
# Test loss:  0.05495, Accuracy: [62.17 73.89] %
# 21.3 %
# Train loss: 0.06084
# Test loss:  0.05457, Accuracy: [62.21 75.16] %
# 21.7 %
# Train loss: 0.06771
# Test loss:  0.05789, Accuracy: [58.53 72.33] %
# 22.0 %
# Train loss: 0.06140
# Test loss:  0.05846, Accuracy: [57.42 72.01] %
# 22.3 %
# Train loss: 0.06326
# Test loss:  0.06005, Accuracy: [57.49 69.66] %
# 22.7 %
# Train loss: 0.06028
# Test loss:  0.05575, Accuracy: [62.4  74.54] %
# 23.0 %
# Train loss: 0.47773
# Test loss:  0.21305, Accuracy: [ 1.07 14.16] %
# 23.3 %
# Train loss: 0.06550
# Test loss:  0.05558, Accuracy: [63.67 72.98] %
# 23.7 %
# Train loss: 0.06111
# Test loss:  0.05233, Accuracy: [63.18 77.28] %
# 24.0 %
# Train loss: 0.05969
# Test loss:  0.05360, Accuracy: [65.04 75.2 ] %
# 24.3 %
# Train loss: 0.05951
# Test loss:  0.05638, Accuracy: [62.57 72.82] %
# 24.7 %
# Train loss: 0.05997
# Test loss:  0.05153, Accuracy: [66.02 77.9 ] %
# 25.0 %
# Train loss: 0.05784
# Test loss:  0.05689, Accuracy: [58.46 72.07] %
# 25.3 %
# Train loss: 0.05844
# Test loss:  0.05352, Accuracy: [64.39 75.03] %
# 25.7 %
# Train loss: 0.05795
# Test loss:  0.05749, Accuracy: [61.69 70.77] %
# 26.0 %
# Train loss: 0.05789
# Test loss:  0.05111, Accuracy: [65.43 77.9 ] %
# 26.3 %
# Train loss: 0.05720
# Test loss:  0.05186, Accuracy: [65.43 76.86] %
# 26.7 %
# Train loss: 0.14947
# Test loss:  0.09102, Accuracy: [28.91 61.13] %
# 27.0 %
# Train loss: 0.06118
# Test loss:  0.05151, Accuracy: [67.15 75.98] %
# 27.3 %
# Train loss: 0.05776
# Test loss:  0.05314, Accuracy: [65.01 75.52] %
# 27.7 %
# Train loss: 0.05679
# Test loss:  0.05114, Accuracy: [65.66 78.65] %
# 28.0 %
# Train loss: 0.05606
# Test loss:  0.05164, Accuracy: [66.28 76.46] %
# 28.3 %
# Train loss: 0.05431
# Test loss:  0.05293, Accuracy: [65.2  75.81] %
# 28.7 %
# Train loss: 0.05662
# Test loss:  0.05321, Accuracy: [63.51 77.47] %
# 29.0 %
# Train loss: 0.05550
# Test loss:  0.05311, Accuracy: [64.26 76.6 ] %
# 29.3 %
# Train loss: 0.05454
# Test loss:  0.05467, Accuracy: [64.13 74.15] %
# 29.7 %
# Train loss: 0.05515
# Test loss:  0.05272, Accuracy: [65.76 75.85] %
# 30.0 %
# Train loss: 0.05551
# Test loss:  0.05326, Accuracy: [61.33 75.98] %
# 30.3 %
# Train loss: 0.05406
# Test loss:  0.05161, Accuracy: [63.44 77.25] %
# 30.7 %
# Train loss: 0.05441
# Test loss:  0.05128, Accuracy: [66.34 78.29] %
# 31.0 %
# Train loss: 0.64384
# Test loss:  0.21251, Accuracy: [3.19 4.72] %
# 31.3 %
# Train loss: 0.05910
# Test loss:  0.05349, Accuracy: [63.09 76.89] %
# 31.7 %
# Train loss: 0.05533
# Test loss:  0.05241, Accuracy: [65.59 76.6 ] %
# 32.0 %
# Train loss: 0.05337
# Test loss:  0.05010, Accuracy: [66.83 79.04] %
# 32.3 %
# Train loss: 0.05417
# Test loss:  0.04921, Accuracy: [67.97 79.59] %
# 32.7 %
# Train loss: 0.05268
# Test loss:  0.05158, Accuracy: [66.83 76.82] %
# 33.0 %
# Train loss: 0.05294
# Test loss:  0.05129, Accuracy: [66.86 77.73] %
# 33.3 %
# Train loss: 0.29559
# Test loss:  0.25562, Accuracy: [3.42 1.46] %
# 33.7 %
# Train loss: 0.06829
# Test loss:  0.05893, Accuracy: [63.51 68.65] %
# 34.0 %
# Train loss: 0.05781
# Test loss:  0.05135, Accuracy: [65.46 77.47] %
# 34.3 %
# Train loss: 0.05483
# Test loss:  0.04903, Accuracy: [65.92 80.18] %
# 34.7 %
# Train loss: 0.05320
# Test loss:  0.05095, Accuracy: [64.94 79.65] %
# 35.0 %
# Train loss: 0.05241
# Test loss:  0.05042, Accuracy: [65.79 77.41] %
# 35.3 %
# Train loss: 0.05176
# Test loss:  0.04923, Accuracy: [67.29 80.27] %
# 35.7 %
# Train loss: 0.05175
# Test loss:  0.04850, Accuracy: [67.87 81.02] %
# 36.0 %
# Train loss: 0.05150
# Test loss:  0.04865, Accuracy: [68.33 80.31] %
# 36.3 %
# Train loss: 0.05078
# Test loss:  0.05031, Accuracy: [66.34 79.52] %
# 36.7 %
# Train loss: 0.05040
# Test loss:  0.04877, Accuracy: [67.29 80.44] %
# 37.0 %
# Train loss: 0.04984
# Test loss:  0.05147, Accuracy: [65.72 77.77] %
# 37.3 %
# Train loss: 0.05015
# Test loss:  0.04870, Accuracy: [67.71 81.02] %
# 37.7 %
# Train loss: 0.05028
# Test loss:  0.04896, Accuracy: [67.84 80.21] %
# 38.0 %
# Train loss: 0.05018
# Test loss:  0.04745, Accuracy: [68.82 80.99] %
# 38.3 %
# Train loss: 0.04891
# Test loss:  0.04942, Accuracy: [67.45 79.88] %
# 38.7 %
# Train loss: 0.04993
# Test loss:  0.04865, Accuracy: [68.52 80.31] %
# 39.0 %
# Train loss: 0.04962
# Test loss:  0.04775, Accuracy: [68.36 81.48] %
# 39.3 %
# Train loss: 0.04969
# Test loss:  0.05003, Accuracy: [66.5  79.39] %
# 39.7 %
# Train loss: 0.04870
# Test loss:  0.04766, Accuracy: [69.08 81.02] %
# 40.0 %
# Train loss: 0.05000
# Test loss:  0.04788, Accuracy: [68.23 80.6 ] %
# 40.3 %
# Train loss: 0.04963
# Test loss:  0.04679, Accuracy: [69.01 81.74] %
# 40.7 %
# Train loss: 0.04847
# Test loss:  0.04865, Accuracy: [67.19 80.37] %
# 41.0 %
# Train loss: 0.04878
# Test loss:  0.04692, Accuracy: [69.27 81.97] %
# 41.3 %
# Train loss: 0.04851
# Test loss:  0.04893, Accuracy: [68.13 80.89] %
# 41.7 %
# Train loss: 0.04875
# Test loss:  0.04944, Accuracy: [67.35 80.27] %
# 42.0 %
# Train loss: 0.04807
# Test loss:  0.04704, Accuracy: [68.39 81.45] %
# 42.3 %
# Train loss: 0.04833
# Test loss:  0.04674, Accuracy: [68.78 81.61] %
# 42.7 %
# Train loss: 0.04841
# Test loss:  0.04671, Accuracy: [69.69 81.77] %
# 43.0 %
# Train loss: 0.04869
# Test loss:  0.04714, Accuracy: [69.27 81.74] %
# 43.3 %
# Train loss: 0.04779
# Test loss:  0.04803, Accuracy: [68.75 80.92] %
# 43.7 %
# Train loss: 0.04803
# Test loss:  0.04988, Accuracy: [67.19 79.49] %
# 44.0 %
# Train loss: 0.04983
# Test loss:  0.04638, Accuracy: [69.76 82.1 ] %
# 44.3 %
# Train loss: 0.04803
# Test loss:  0.04965, Accuracy: [66.83 79.65] %
# 44.7 %
# Train loss: 0.04755
# Test loss:  0.04625, Accuracy: [69.3  82.55] %
# 45.0 %
# Train loss: 0.04760
# Test loss:  0.04963, Accuracy: [67.32 80.24] %
# 45.3 %
# Train loss: 0.04717
# Test loss:  0.04804, Accuracy: [68.68 80.4 ] %
# 45.7 %
# Train loss: 0.04738
# Test loss:  0.04687, Accuracy: [68.33 81.58] %
# 46.0 %
# Train loss: 0.04715
# Test loss:  0.04598, Accuracy: [69.92 82.85] %
# 46.3 %
# Train loss: 0.04686
# Test loss:  0.04626, Accuracy: [68.75 82.52] %
# 46.7 %
# Train loss: 0.04739
# Test loss:  0.04780, Accuracy: [68.42 81.58] %
# 47.0 %
# Train loss: 0.04631
# Test loss:  0.04794, Accuracy: [69.4  80.76] %
# 47.3 %
# Train loss: 0.04571
# Test loss:  0.04911, Accuracy: [68.39 79.69] %
# 47.7 %
# Train loss: 0.04640
# Test loss:  0.04606, Accuracy: [69.63 82.91] %
# 48.0 %
# Train loss: 0.04684
# Test loss:  0.04926, Accuracy: [68.36 79.3 ] %
# 48.3 %
# Train loss: 0.04609
# Test loss:  0.04849, Accuracy: [68.29 81.54] %
# 48.7 %
# Train loss: 0.04599
# Test loss:  0.04732, Accuracy: [68.1 82.1] %
# 49.0 %
# Train loss: 0.04555
# Test loss:  0.04691, Accuracy: [70.54 81.35] %
# 49.3 %
# Train loss: 0.04635
# Test loss:  0.04883, Accuracy: [68.26 81.32] %
# 49.7 %
# Train loss: 0.04624
# Test loss:  0.04662, Accuracy: [70.18 82.58] %
# 50.0 %
# Train loss: 0.04600
# Test loss:  0.04753, Accuracy: [70.35 80.92] %
# 50.3 %
# Train loss: 0.04577
# Test loss:  0.04944, Accuracy: [67.58 80.08] %
# 50.7 %
# Train loss: 0.04548
# Test loss:  0.04635, Accuracy: [70.57 82.65] %
# 51.0 %
# Train loss: 0.04486
# Test loss:  0.04770, Accuracy: [69.43 81.05] %
# 51.3 %
# Train loss: 0.04578
# Test loss:  0.04605, Accuracy: [71.45 82.85] %
# 51.7 %
# Train loss: 0.04472
# Test loss:  0.04559, Accuracy: [70.67 82.16] %
# 52.0 %
# Train loss: 0.04586
# Test loss:  0.04587, Accuracy: [70.25 82.65] %
# 52.3 %
# Train loss: 0.04505
# Test loss:  0.04732, Accuracy: [70.93 81.38] %
# 52.7 %
# Train loss: 0.04498
# Test loss:  0.04569, Accuracy: [70.96 82.98] %
# 53.0 %
# Train loss: 0.04563
# Test loss:  0.04806, Accuracy: [70.35 80.01] %
# 53.3 %
# Train loss: 0.04509
# Test loss:  0.04646, Accuracy: [70.18 82.49] %
# 53.7 %
# Train loss: 0.04411
# Test loss:  0.04725, Accuracy: [70.18 81.35] %
# 54.0 %
# Train loss: 0.04504
# Test loss:  0.04800, Accuracy: [70.21 80.99] %
# 54.3 %
# Train loss: 0.04408
# Test loss:  0.04825, Accuracy: [68.98 80.4 ] %
# 54.7 %
# Train loss: 0.04475
# Test loss:  0.04690, Accuracy: [70.8  81.35] %
# 55.0 %
# Train loss: 0.04429
# Test loss:  0.04784, Accuracy: [70.51 80.89] %
# 55.3 %
# Train loss: 0.04373
# Test loss:  0.04687, Accuracy: [71.03 81.61] %
# 55.7 %
# Train loss: 0.04433
# Test loss:  0.04596, Accuracy: [69.79 82.62] %
# 56.0 %
# Train loss: 0.04460
# Test loss:  0.04587, Accuracy: [70.57 82.78] %
# 56.3 %
# Train loss: 0.04454
# Test loss:  0.04901, Accuracy: [69.82 79.52] %
# 56.7 %
# Train loss: 0.04412
# Test loss:  0.04825, Accuracy: [69.37 81.12] %
# 57.0 %
# Train loss: 0.04377
# Test loss:  0.04676, Accuracy: [70.38 82.16] %
# 57.3 %
# Train loss: 0.04413
# Test loss:  0.04669, Accuracy: [71.06 81.41] %
# 57.7 %
# Train loss: 0.04314
# Test loss:  0.04752, Accuracy: [70.48 81.38] %
# 58.0 %
# Train loss: 0.04397
# Test loss:  0.04720, Accuracy: [70.54 81.64] %
# 58.3 %
# Train loss: 0.04394
# Test loss:  0.04864, Accuracy: [69.95 79.75] %
# 58.7 %
# Train loss: 0.04418
# Test loss:  0.04813, Accuracy: [70.12 79.95] %
# 59.0 %
# Train loss: 0.04350
# Test loss:  0.04770, Accuracy: [70.61 80.31] %
# 59.3 %
# Train loss: 0.04320
# Test loss:  0.04776, Accuracy: [70.05 81.09] %
# 59.7 %
# Train loss: 0.04269
# Test loss:  0.04564, Accuracy: [71.32 82.1 ] %
# 60.0 %
# Train loss: 0.04400
# Test loss:  0.05189, Accuracy: [67.45 75.36] %
# 60.3 %
# Train loss: 0.04342
# Test loss:  0.04824, Accuracy: [69.53 80.18] %
# 60.7 %
# Train loss: 0.04321
# Test loss:  0.04825, Accuracy: [70.57 79.95] %
# 61.0 %
# Train loss: 0.04336
# Test loss:  0.04671, Accuracy: [71.55 81.61] %
# 61.3 %
# Train loss: 0.04293
# Test loss:  0.04567, Accuracy: [71.26 83.01] %
# 61.7 %
# Train loss: 0.04298
# Test loss:  0.04668, Accuracy: [71.39 81.9 ] %
# 62.0 %
# Train loss: 0.04309
# Test loss:  0.04729, Accuracy: [70.12 81.84] %
# 62.3 %
# Train loss: 0.04318
# Test loss:  0.04683, Accuracy: [71.22 81.61] %
# 62.7 %
# Train loss: 0.04327
# Test loss:  0.04801, Accuracy: [71.09 79.69] %
# 63.0 %
# Train loss: 0.04274
# Test loss:  0.04641, Accuracy: [71.03 82.52] %
# 63.3 %
# Train loss: 0.04330
# Test loss:  0.04722, Accuracy: [71.68 80.4 ] %
# 63.7 %
# Train loss: 0.04336
# Test loss:  0.04755, Accuracy: [71.   80.27] %
# 64.0 %
# Train loss: 0.04278
# Test loss:  0.04873, Accuracy: [70.44 78.97] %
# 64.3 %
# Train loss: 0.04256
# Test loss:  0.05015, Accuracy: [68.68 77.96] %
# 64.7 %
# Train loss: 0.04211
# Test loss:  0.04512, Accuracy: [71.42 83.4 ] %
# 65.0 %
# Train loss: 0.04185
# Test loss:  0.04786, Accuracy: [70.05 81.32] %
# 65.7 %
# Train loss: 0.04263
# Test loss:  0.04831, Accuracy: [70.41 79.49] %
# 66.0 %
# Train loss: 0.04248
# Test loss:  0.04857, Accuracy: [69.34 80.37] %
# 66.3 %
# Train loss: 0.04249
# Test loss:  0.04829, Accuracy: [71.03 79.23] %
# 66.7 %
# Train loss: 0.04242
# Test loss:  0.04933, Accuracy: [68.59 78.65] %
# 67.0 %
# Train loss: 0.04249
# Test loss:  0.04696, Accuracy: [70.77 81.28] %
# 67.3 %
# Train loss: 0.04193
# Test loss:  0.04975, Accuracy: [68.2  78.94] %
# 67.7 %
# Train loss: 0.04239
# Test loss:  0.04801, Accuracy: [70.35 80.31] %
# 68.0 %
# Train loss: 0.04217
# Test loss:  0.05012, Accuracy: [68.55 78.65] %
# 68.3 %
# Train loss: 0.04176
# Test loss:  0.04708, Accuracy: [69.56 82.62] %
# 68.7 %
# Train loss: 0.04237
# Test loss:  0.04759, Accuracy: [70.67 80.89] %
# 69.0 %
# Train loss: 0.04158
# Test loss:  0.04806, Accuracy: [70.8  79.75] %
# 69.3 %
# Train loss: 0.04191
# Test loss:  0.04695, Accuracy: [71.48 80.86] %
# 69.7 %
# Train loss: 0.04208
# Test loss:  0.04724, Accuracy: [71.55 81.74] %
# 70.0 %
# Train loss: 0.04210
# Test loss:  0.04991, Accuracy: [68.95 77.47] %
# 70.3 %
# Train loss: 0.04186
# Test loss:  0.04595, Accuracy: [71.65 83.4 ] %
# 70.7 %
# Train loss: 0.04184
# Test loss:  0.04900, Accuracy: [68.39 81.18] %
# 71.0 %
# Train loss: 0.04178
# Test loss:  0.04589, Accuracy: [72.1  82.03] %
# 71.3 %
# Train loss: 0.04177
# Test loss:  0.04977, Accuracy: [68.85 78.45] %
# 71.7 %
# Train loss: 0.04178
# Test loss:  0.04555, Accuracy: [71.71 82.85] %
# 72.0 %
# Train loss: 0.04168
# Test loss:  0.04686, Accuracy: [72.36 80.83] %
# 72.3 %
# Train loss: 0.04222
# Test loss:  0.04757, Accuracy: [71.13 80.96] %
# 72.7 %
# Train loss: 0.04146
# Test loss:  0.04888, Accuracy: [69.4  80.11] %
# 73.0 %
# Train loss: 0.04176
# Test loss:  0.04637, Accuracy: [71.81 81.38] %
# 73.3 %
# Train loss: 0.04151
# Test loss:  0.04658, Accuracy: [70.7  82.85] %
# 73.7 %
# Train loss: 0.04167
# Test loss:  0.04650, Accuracy: [72.33 80.7 ] %
# 74.0 %
# Train loss: 0.04164
# Test loss:  0.04723, Accuracy: [70.7  80.86] %
# 74.3 %
# Train loss: 0.04170
# Test loss:  0.04657, Accuracy: [71.   82.03] %
# 74.7 %
# Train loss: 0.04095
# Test loss:  0.04894, Accuracy: [68.68 80.37] %
# 75.0 %
# Train loss: 0.04131
# Test loss:  0.04830, Accuracy: [69.86 80.14] %
# 75.3 %
# Train loss: 0.04154
# Test loss:  0.04780, Accuracy: [69.92 80.7 ] %
# 75.7 %
# Train loss: 0.04160
# Test loss:  0.04624, Accuracy: [71.94 81.41] %
# 76.0 %
# Train loss: 0.04134
# Test loss:  0.04476, Accuracy: [72.27 83.79] %
# 76.3 %
# Train loss: 0.04124
# Test loss:  0.04698, Accuracy: [71.55 80.92] %
# 76.7 %
# Train loss: 0.04114
# Test loss:  0.04797, Accuracy: [70.08 80.83] %
# 77.0 %
# Train loss: 0.04121
# Test loss:  0.04732, Accuracy: [71.16 80.66] %
# 77.3 %
# Train loss: 0.04125
# Test loss:  0.04469, Accuracy: [72.79 83.98] %
# 77.7 %
# Train loss: 0.04131
# Test loss:  0.04705, Accuracy: [70.05 82.23] %
# 78.0 %
# Train loss: 0.04116
# Test loss:  0.04729, Accuracy: [70.74 81.32] %
# 78.3 %
# Train loss: 0.04083
# Test loss:  0.04923, Accuracy: [69.56 79.43] %
# 78.7 %
# Train loss: 0.04127
# Test loss:  0.04556, Accuracy: [72.75 82.23] %
# 79.0 %
# Train loss: 0.04099
# Test loss:  0.04783, Accuracy: [70.74 79.98] %
# 79.3 %
# Train loss: 0.04144
# Test loss:  0.04701, Accuracy: [70.38 81.48] %
# 79.7 %
# Train loss: 0.04138
# Test loss:  0.04733, Accuracy: [70.44 81.25] %
# 80.0 %
# Train loss: 0.04105
# Test loss:  0.04569, Accuracy: [71.91 82.45] %
# 80.3 %
# Train loss: 0.04095
# Test loss:  0.04652, Accuracy: [71.35 81.84] %
# 80.7 %
# Train loss: 0.04084
# Test loss:  0.04740, Accuracy: [69.89 82.32] %
# 81.0 %
# Train loss: 0.04102
# Test loss:  0.04645, Accuracy: [71.35 81.61] %
# 81.3 %
# Train loss: 0.04113
# Test loss:  0.04617, Accuracy: [71.55 82.78] %
# 81.7 %
# Train loss: 0.04088
# Test loss:  0.04737, Accuracy: [70.25 81.28] %
# 82.0 %
# Train loss: 0.04064
# Test loss:  0.04514, Accuracy: [71.71 83.76] %
# 82.3 %
# Train loss: 0.04082
# Test loss:  0.04932, Accuracy: [69.08 78.74] %
# 82.7 %
# Train loss: 0.04081
# Test loss:  0.04946, Accuracy: [68.68 78.84] %
# 83.0 %
# Train loss: 0.04073
# Test loss:  0.04794, Accuracy: [70.35 79.95] %
# 83.3 %
# Train loss: 0.04117
# Test loss:  0.04910, Accuracy: [69.27 78.32] %
# 83.7 %
# Train loss: 0.04089
# Test loss:  0.04670, Accuracy: [71.29 81.61] %
# 84.0 %
# Train loss: 0.04084
# Test loss:  0.04633, Accuracy: [72.27 81.48] %
# 84.3 %
# Train loss: 0.04080
# Test loss:  0.04641, Accuracy: [70.96 82.71] %
# 84.7 %
# Train loss: 0.04068
# Test loss:  0.04693, Accuracy: [70.87 81.15] %
# 85.0 %
# Train loss: 0.04061
# Test loss:  0.04884, Accuracy: [70.35 79.23] %
# 85.3 %
# Train loss: 0.04046
# Test loss:  0.04748, Accuracy: [70.57 80.83] %
# 85.7 %
# Train loss: 0.04048
# Test loss:  0.04705, Accuracy: [71.13 81.02] %
# 86.0 %
# Train loss: 0.04047
# Test loss:  0.04811, Accuracy: [70.25 79.39] %
# 86.3 %
# Train loss: 0.04077
# Test loss:  0.04691, Accuracy: [71.32 81.87] %
# 86.7 %
# Train loss: 0.04019
# Test loss:  0.04549, Accuracy: [72.62 83.07] %
# 87.0 %
# Train loss: 0.04054
# Test loss:  0.04764, Accuracy: [70.38 80.92] %
# 87.3 %
# Train loss: 0.04063
# Test loss:  0.04660, Accuracy: [71.74 81.28] %
# 87.7 %
# Train loss: 0.03997
# Test loss:  0.04842, Accuracy: [69.82 80.08] %
# 88.0 %
# Train loss: 0.04031
# Test loss:  0.04648, Accuracy: [71.48 81.77] %
# 88.3 %
# Train loss: 0.04024
# Test loss:  0.04660, Accuracy: [71.45 82.  ] %
# 88.7 %
# Train loss: 0.04033
# Test loss:  0.04534, Accuracy: [72.3  83.01] %
# 89.0 %
# Train loss: 0.04017
# Test loss:  0.04829, Accuracy: [69.86 80.11] %
# 89.3 %
# Train loss: 0.04021
# Test loss:  0.04779, Accuracy: [70.77 80.63] %
# 89.7 %
# Train loss: 0.04050
# Test loss:  0.04530, Accuracy: [71.48 83.69] %
# 90.0 %
# Train loss: 0.04040
# Test loss:  0.04679, Accuracy: [71.78 80.92] %
# 90.3 %
# Train loss: 0.03993
# Test loss:  0.04618, Accuracy: [71.22 83.2 ] %
# 90.7 %
# Train loss: 0.04038
# Test loss:  0.04564, Accuracy: [71.94 83.01] %
# 91.0 %
# Train loss: 0.04017
# Test loss:  0.04878, Accuracy: [69.73 79.52] %
# 91.3 %
# Train loss: 0.04010
# Test loss:  0.04579, Accuracy: [72.43 82.75] %
# 91.7 %
# Train loss: 0.04003
# Test loss:  0.04729, Accuracy: [70.12 81.9 ] %
# 92.0 %
# Train loss: 0.04004
# Test loss:  0.04876, Accuracy: [70.02 79.13] %
# 92.3 %
# Train loss: 0.03993
# Test loss:  0.04762, Accuracy: [69.01 82.39] %
# 92.7 %
# Train loss: 0.04030
# Test loss:  0.04815, Accuracy: [70.38 79.43] %
# 93.0 %
# Train loss: 0.04012
# Test loss:  0.04651, Accuracy: [71.74 81.97] %
# 93.3 %
# Train loss: 0.03996
# Test loss:  0.04632, Accuracy: [71.   82.06] %
# 93.7 %
# Train loss: 0.04021
# Test loss:  0.04652, Accuracy: [70.87 82.55] %
# 94.0 %
# Train loss: 0.03980
# Test loss:  0.04674, Accuracy: [71.52 81.97] %
# 94.3 %
# Train loss: 0.03987
# Test loss:  0.04689, Accuracy: [70.87 82.03] %
# 94.7 %
# Train loss: 0.03974
# Test loss:  0.04631, Accuracy: [70.7  82.52] %
# 95.0 %
# Train loss: 0.03994
# Test loss:  0.04611, Accuracy: [71.03 82.71] %
# 95.3 %
# Train loss: 0.03974
# Test loss:  0.04550, Accuracy: [71.58 82.88] %
# 95.7 %
# Train loss: 0.03996
# Test loss:  0.04593, Accuracy: [71.45 82.85] %
# 96.0 %
# Train loss: 0.04020
# Test loss:  0.04613, Accuracy: [71.45 82.78] %
# 96.3 %
# Train loss: 0.03964
# Test loss:  0.04670, Accuracy: [71.   82.45] %
# 96.7 %
# Train loss: 0.04004
# Test loss:  0.04576, Accuracy: [72.2  82.81] %
# 97.0 %
# Train loss: 0.03963
# Test loss:  0.04745, Accuracy: [69.89 81.51] %
# 97.3 %
# Train loss: 0.03981
# Test loss:  0.04522, Accuracy: [72.17 83.2 ] %
# 97.7 %
# Train loss: 0.03979
# Test loss:  0.04557, Accuracy: [71.74 83.33] %
# 98.0 %
# Train loss: 0.03968
# Test loss:  0.04623, Accuracy: [70.77 82.62] %
# 98.3 %
# Train loss: 0.03959
# Test loss:  0.04493, Accuracy: [73.4  83.37] %
# 98.7 %
# Train loss: 0.03960
# Test loss:  0.04630, Accuracy: [71.09 82.52] %
# 99.0 %
# Train loss: 0.03939
# Test loss:  0.04485, Accuracy: [72.1  83.72] %
# 99.3 %
# Train loss: 0.03980
# Test loss:  0.04533, Accuracy: [71.84 83.46] %
# 99.7 %
# CPU times: user 6h 39min 42s, sys: 28.5 s, total: 6h 40min 11s
# Wall time: 6h 42min 38s

# %%
torch.save(model.state_dict(), f'/nfs/pic.es/user/m/mgraell/Halo_ML/{save_file}')

# %% [markdown]
# # Anàlisi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import networkx as nx
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
import scipy as scp
from funcions_v2 import *


device = 'cuda' if torch.cuda.is_available() else 'cpu'
device

class Model(nn.Module):
    def __init__(self, input_len:int, output_len:int, batch_size:int):
        super().__init__()
                        
        self.lin_block = nn.Sequential(
                                nn.Linear(input_len, 256),
                                nn.ELU(),
                                nn.Linear(256, 256),                                
                            )
        self.lin_block2 = nn.Sequential(
                                nn.Linear(256, 256),
                                nn.ELU(),
                                nn.Linear(256, output_len),
                            )
        self.batch_size = batch_size
        self.input_len = input_len
        self.output_len = output_len



    def forward(self, data):
        x = [self.lin_block(x_elem.to(device)) for x_elem in data]
        # xsum =[xx.sum(0) for xx in x]
        # x = torch.stack(xsum)
        
        max_len = max([len(x_elem) for x_elem in data])

        padded_x = [torch.nn.functional.pad(x_elem, (0, 0, 0, max_len - len(x_elem))) for x_elem in x]

        stacked_data = torch.stack(padded_x)

        x = stacked_data.sum(dim=1)
        
        output = self.lin_block2(x)

        return output.squeeze()
    
torch.manual_seed(42)
input_len = 6
output_len = 2
model = Model(input_len=input_len, output_len=output_len, batch_size = 128).to(device)
model.load_state_dict(torch.load('/nfs/pic.es/user/m/mgraell/Halo_ML/bctoa_model_blau_0.pt'))

X_test_tot = torch.load('/nfs/pic.es/user/m/mgraell/Halo_ML/X_test_full_bctoa')
y_test_tot = torch.tensor(np.array(torch.load('/nfs/pic.es/user/m/mgraell/Halo_ML/y_test_full_bctoa')))
X_test_analitic = torch.load('/nfs/pic.es/user/m/mgraell/Halo_ML/X_test_analitic_bctoa')
print(len(X_test_tot), len(X_test_analitic), y_test_tot.shape)
# Out:
# 40 40 torch.Size([40, 128, 2])

# %%
for i in range(len(X_test_tot)):
    for j in range(len(X_test_tot[i])):
        X_test_tot[i][j] = torch.tensor(np.array(X_test_tot[i][j]))
        X_test_analitic[i][j] = torch.tensor(np.array(X_test_analitic[i][j]))

# %%
model.eval()

labels_tot_list = []
preds_tot_list = []
preds_analitic_tot_list = []


nan_index0 = []
nan_index1 = []
with torch.inference_mode():
    preds_tot = np.array([model(batch).cpu().numpy() for batch in X_test_tot])
    labels_tot = y_test_tot.cpu().numpy()
    print(preds_tot.shape)
    print(labels_tot.shape)
    preds_tot = preds_tot.reshape(preds_tot.shape[0]*preds_tot.shape[1], preds_tot.shape[2])
    labels_tot = labels_tot.reshape(labels_tot.shape[0]*labels_tot.shape[1], labels_tot.shape[2])
    for i in range(len(X_test_analitic)):
        preds_analitic = []
        for j in range(len(X_test_analitic[i])):
            computeshape3d = compute_shape_3D(X_test_analitic[i][j][:,0].numpy(),X_test_analitic[i][j][:,1].numpy(),
                                              X_test_analitic[i][j][:,2].numpy(), 'standard')
            preds_analitic.append(np.array([computeshape3d[1][1]/computeshape3d[1][0], computeshape3d[1][2]/computeshape3d[1][0]]))
        preds_analitic_tot_list.append(np.array(preds_analitic))
    preds_analitic_tot = np.array(preds_analitic_tot_list)
    print(preds_analitic_tot.shape)
    preds_analitic_tot = preds_analitic_tot.reshape(preds_analitic_tot.shape[0]*preds_analitic_tot.shape[1], preds_analitic_tot.shape[2])

    print(preds_analitic_tot.shape)
    
    preds_analitic_btoa = preds_analitic_tot[:,0]
    preds_analitic_ctoa = preds_analitic_tot[:,1]

    for i in range(len(preds_analitic_btoa)):
        if np.isnan(preds_analitic_btoa[i]):
            nan_index0.append(i)
    inds_to_delete0 = sorted(nan_index0, reverse=True)
    for i in range(len(preds_analitic_ctoa)):
        if np.isnan(preds_analitic_ctoa[i]):
            nan_index1.append(i)
    inds_to_delete1 = sorted(nan_index1, reverse=True)
    
    labels_analitic_btoa = labels_tot[:,0]
    labels_analitic_ctoa = labels_tot[:,1]
    
    for i in inds_to_delete0:
        labels_analitic_btoa = np.delete(labels_analitic_btoa, i)
        preds_analitic_btoa = np.delete(preds_analitic_btoa, i)
    for i in inds_to_delete1:
        labels_analitic_ctoa = np.delete(labels_analitic_ctoa, i)
        preds_analitic_ctoa = np.delete(preds_analitic_ctoa, i)

    
    print(labels_tot.shape, preds_tot.shape, labels_analitic_btoa.shape, preds_analitic_btoa.shape)
    

    corr_btoa = np.corrcoef(labels_tot[:,0], preds_tot[:,0])[0,1]
    corr_ctoa = np.corrcoef(labels_tot[:,1], preds_tot[:,1])[0,1]
    corr_analitic_btoa = np.corrcoef(labels_analitic_btoa, preds_analitic_btoa)[0,1]
    corr_analitic_ctoa = np.corrcoef(labels_analitic_ctoa, preds_analitic_ctoa)[0,1]
    
    

    
    
    plt.plot(labels_tot[:,0], preds_tot[:,0], '.', color = 'r', markersize = .5, label='Model predictions')
    plt.plot(labels_analitic_btoa, preds_analitic_btoa, '.', color = 'g', markersize = .5, label='Analytic calculation')
    plt.title('b/a')
    plt.legend()



    print('b/a r2:', np.round(corr_btoa, 2), '|', 'c/a r2:', np.round(corr_ctoa, 2))
    print('Analytic b/a r2:', np.round(corr_analitic_btoa, 2), '|', 'Analytic c/a r2:', np.round(corr_analitic_ctoa, 2))
    plt.plot(np.array([0.3,0.4,0.5,0.6,0.7,0.8,0.9,1]),np.array([0.3,0.4,0.5,0.6,0.7,0.8,0.9,1]), '--', color = 'cornflowerblue')

    plt.xlim(0.3,1)
    plt.ylim(0.3,1)
    plt.show()

    plt.plot(labels_tot[:,1], preds_tot[:,1], '.', color = 'r', markersize = .5, label='Model predictions')
    plt.plot(labels_analitic_ctoa, preds_analitic_ctoa, '.', color = 'g', markersize = .5, label='Analytic calculation')
    plt.title('c/a')
    plt.legend()


print('b/a r2:', np.round(corr_btoa, 2), '|', 'c/a r2:', np.round(corr_ctoa, 2))
print('Analytic b/a r2:', np.round(corr_analitic_btoa, 2), '|', 'Analytic c/a r2:', np.round(corr_analitic_ctoa, 2))
plt.plot(np.array([0.3,0.4,0.5,0.6,0.7,0.8,0.9,1]),np.array([0.3,0.4,0.5,0.6,0.7,0.8,0.9,1]), '--', color = 'cornflowerblue')

plt.xlim(0.3,1)
plt.ylim(0.3,1)
plt.show()




bins_number = 20


binstat = scp.stats.binned_statistic(labels_tot[:,0], preds_tot[:,0], statistic='mean', bins=bins_number, range=None)
preds_bins = binstat[0]
labels_bins = binstat[1]
labels_bins = np.delete(labels_bins, 0)

binstat_analitic = scp.stats.binned_statistic(labels_analitic_btoa, preds_analitic_btoa, statistic='mean', bins=bins_number, range=None)
preds_analitic_bins = binstat_analitic[0]

plt.plot(labels_bins, preds_bins, '-', color = 'r', label='Model predictions')
plt.plot(labels_bins, preds_analitic_bins, '-', color = 'g', label='Analytic calculation')
plt.title('b/a, binned')
plt.legend()

plt.plot([0.3,1],[0.3,1], '--', color = 'cornflowerblue')
plt.show()

binstat = scp.stats.binned_statistic(labels_tot[:,1], preds_tot[:,1], statistic='mean', bins=bins_number, range=None)
preds_bins = binstat[0]
labels_bins = binstat[1]
labels_bins = np.delete(labels_bins, 0)

binstat_analitic = scp.stats.binned_statistic(labels_analitic_ctoa, preds_analitic_ctoa, statistic='mean', bins=bins_number, range=None)
preds_analitic_bins = binstat_analitic[0]

plt.plot(labels_bins, preds_bins, '-', color = 'r', label='Model predictions')
plt.plot(labels_bins, preds_analitic_bins, '-', color = 'g', label='Analytic calculation')
plt.title('c/a, binned')
plt.legend()

plt.plot([0.3,1],[0.3,1], '--', color = 'cornflowerblue', linewidth = '1')
plt.show()
# Out:
# (40, 128, 2)
# (40, 128, 2)
# /nfs/pic.es/user/m/mgraell/Halo_ML/funcions_v2.py:196: RuntimeWarning: invalid value encountered in sqrt
#   return v3d,np.sqrt(w3d)
# (40, 128, 2)
# (5120, 2)
# (5120, 2) (5120, 2) (5120,) (5120,)
# b/a r2: 0.62 | c/a r2: 0.49
# Analytic b/a r2: 0.64 | Analytic c/a r2: 0.66
# b/a r2: 0.62 | c/a r2: 0.49
# Analytic b/a r2: 0.64 | Analytic c/a r2: 0.66
